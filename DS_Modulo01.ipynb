# %% [markdown]
# <a href="https://colab.research.google.com/github/brunarigo/datascience2-alurabootcamp/blob/main/DS_Modulo01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Analisando dados da Saúde com Python e Pandas**
#
# Bootcamp Data Science Aplicada 2 - Alura - 05/2021

# %% [markdown]
# ##Aula 01 - Aquisição e Leitura de Dados Reais - DataSUS
#
# **Estudos realizados utilizando os dados provenientes da Data de Atendimento**

# %%
import pandas as pd

# %%
dados = pd.read_csv("/content/A205155189_28_143_208_DTProcessamento.csv", encoding="ISO-8859-1", engine="python",
                    skiprows = 3, sep=";", skipfooter=12,
                    thousands=".", decimal=",")
dados.head()
# Out:
#   Unidade da Federação     2008/Jan  ...     2021/Mar         Total
# 0          11 Rondônia   1388528.39  ...  11023309.47  9.964113e+08
# 1              12 Acre    902416.00  ...   4077045.92  4.500485e+08
# 2          13 Amazonas   4735529.42  ...  22032176.22  1.917248e+09
# 3           14 Roraima    657889.53  ...   3985530.08  3.288770e+08
# 4              15 Pará  18864744.11  ...  33276392.89  4.705309e+09
#
# [5 rows x 161 columns]

# %%
dados.tail()
# Out:
#      Unidade da Federação     2008/Jan  ...      2021/Mar         Total
# 22   43 Rio Grande do Sul  30931325.46  ...  1.301552e+08  1.276439e+10
# 23  50 Mato Grosso do Sul   5377392.11  ...  2.516820e+07  2.324525e+09
# 24         51 Mato Grosso   4795299.01  ...  1.961103e+07  2.180120e+09
# 25               52 Goiás  15310637.29  ...  4.559269e+07  4.973574e+09
# 26    53 Distrito Federal   4745919.19  ...  3.183192e+07  2.592423e+09
#
# [5 rows x 161 columns]

# %%
pd.options.display.float_format = "{:.2f}".format

# %%
dados.mean()
# Out:
# 2008/Jan     15126846.64
# 2008/Fev     22710158.12
# 2008/Mar     24594187.35
# 2008/Abr     25431957.83
# 2008/Mai     26511245.91
#                 ...
# 2020/Dez     53377763.15
# 2021/Jan     56073748.02
# 2021/Fev     55578233.31
# 2021/Mar     62502301.42
# Total      6388213338.48
# Length: 159, dtype: float64

# %%
dados["2008/Ago"].mean()
# Out:
# 27800320.306666665

# %% [markdown]
# ###Desafio 01: Escolher Título mais descritivo, que passe a mensagem adequada.

# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

ax = dados.plot(x="Unidade da Federação",y="2008/Ago", kind="bar", figsize=(10,7))
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter("{x:,.2f}"))

plt.title("Valor gasto em Internações no SUS por UF período de Agosto/2008")
plt.show()

# %% [markdown]
# ###Desafio 02: Realizar a análise anterior para mês mais recente

# %%
ax = dados.plot(x="Unidade da Federação",y="2021/Mar", kind="bar", figsize=(10,7))
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter("{x:,.2f}"))

plt.title("Valor gasto em Internações no SUS por UF período de Março/2021")
plt.show()

# %% [markdown]
# ##Aula 2 - Primeiras visualizações de Dados
#
# **Estudos realizados utilizando os dados provenientes da Data de Atendimento**

# %%
dados = pd.read_csv("/content/A091915189_28_143_208_DTAtendimento.csv", encoding="ISO-8859-1", engine="python",
                    skiprows = 3, sep=";", skipfooter=12,
                    thousands=".", decimal=",")
dados.head()
# Out:
#   Unidade da Federação 1992/Mar  ...     2021/Mar         Total
# 0          11 Rondônia        -  ...   4732441.04  9.964113e+08
# 1              12 Acre        -  ...   1137341.65  4.500485e+08
# 2          13 Amazonas        -  ...   6799060.80  1.917248e+09
# 3           14 Roraima        -  ...   2381844.31  3.288770e+08
# 4              15 Pará        -  ...  13069564.31  4.705309e+09
#
# [5 rows x 287 columns]

# %%
dados[['2008/Ago','2008/Set']].head()
# Out:
#       2008/Ago     2008/Set
# 0   2938286.29   2843930.91
# 1   1886871.84   2084884.80
# 2   8331763.97   8148089.92
# 3   1045291.11   1003740.89
# 4  23259148.28  23667690.01

# %%
dados.mean()
# Out:
# 2007/Ago    3.049528e+05
# 2007/Set    7.881453e+05
# 2007/Out    2.440163e+06
# 2007/Nov    5.517354e+06
# 2007/Dez    1.233716e+07
#                 ...
# 2020/Dez    5.377291e+07
# 2021/Jan    4.947411e+07
# 2021/Fev    3.899242e+07
# 2021/Mar    2.416371e+07
# Total       6.388206e+09
# Length: 165, dtype: float64

# %%
colunas_usaveis = dados.mean().index.tolist()
colunas_usaveis.insert(0, "Unidade da Federação")
colunas_usaveis
# Out:
# ['Unidade da Federação',
#  '2007/Ago',
#  '2007/Set',
#  '2007/Out',
#  '2007/Nov',
#  '2007/Dez',
#  '2008/Jan',
#  '2008/Fev',
#  '2008/Mar',
#  '2008/Abr',
#  '2008/Mai',
#  '2008/Jun',
#  '2008/Jul',
#  '2008/Ago',
#  '2008/Set',
#  '2008/Out',
#  '2008/Nov',
#  '2008/Dez',
#  '2009/Jan',
#  '2009/Fev',
#  '2009/Mar',
#  '2009/Abr',
#  '2009/Mai',
#  '2009/Jun',
#  '2009/Jul',
#  '2009/Ago',
#  '2009/Set',
#  '2009/Out',
#  '2009/Nov',
#  '2009/Dez',
#  '2010/Jan',
#  '2010/Fev',
#  '2010/Mar',
#  '2010/Abr',
#  '2010/Mai',
#  '2010/Jun',
#  '2010/Jul',
#  '2010/Ago',
#  '2010/Set',
#  '2010/Out',
#  '2010/Nov',
#  '2010/Dez',
#  '2011/Jan',
#  '2011/Fev',
#  '2011/Mar',
#  '2011/Abr',
#  '2011/Mai',
#  '2011/Jun',
#  '2011/Jul',
#  '2011/Ago',
#  '2011/Set',
#  '2011/Out',
#  '2011/Nov',
#  '2011/Dez',
#  '2012/Jan',
#  '2012/Fev',
#  '2012/Mar',
#  '2012/Abr',
#  '2012/Mai',
#  '2012/Jun',
#  '2012/Jul',
#  '2012/Ago',
#  '2012/Set',
#  '2012/Out',
#  '2012/Nov',
#  '2012/Dez',
#  '2013/Jan',
#  '2013/Fev',
#  '2013/Mar',
#  '2013/Abr',
#  '2013/Mai',
#  '2013/Jun',
#  '2013/Jul',
#  '2013/Ago',
#  '2013/Set',
#  '2013/Out',
#  '2013/Nov',
#  '2013/Dez',
#  '2014/Jan',
#  '2014/Fev',
#  '2014/Mar',
#  '2014/Abr',
#  '2014/Mai',
#  '2014/Jun',
#  '2014/Jul',
#  '2014/Ago',
#  '2014/Set',
#  '2014/Out',
#  '2014/Nov',
#  '2014/Dez',
#  '2015/Jan',
#  '2015/Fev',
#  '2015/Mar',
#  '2015/Abr',
#  '2015/Mai',
#  '2015/Jun',
#  '2015/Jul',
#  '2015/Ago',
#  '2015/Set',
#  '2015/Out',
#  '2015/Nov',
#  '2015/Dez',
#  '2016/Jan',
#  '2016/Fev',
#  '2016/Mar',
#  '2016/Abr',
#  '2016/Mai',
#  '2016/Jun',
#  '2016/Jul',
#  '2016/Ago',
#  '2016/Set',
#  '2016/Out',
#  '2016/Nov',
#  '2016/Dez',
#  '2017/Jan',
#  '2017/Fev',
#  '2017/Mar',
#  '2017/Abr',
#  '2017/Mai',
#  '2017/Jun',
#  '2017/Jul',
#  '2017/Ago',
#  '2017/Set',
#  '2017/Out',
#  '2017/Nov',
#  '2017/Dez',
#  '2018/Jan',
#  '2018/Fev',
#  '2018/Mar',
#  '2018/Abr',
#  '2018/Mai',
#  '2018/Jun',
#  '2018/Jul',
#  '2018/Ago',
#  '2018/Set',
#  '2018/Out',
#  '2018/Nov',
#  '2018/Dez',
#  '2019/Jan',
#  '2019/Fev',
#  '2019/Mar',
#  '2019/Abr',
#  '2019/Mai',
#  '2019/Jun',
#  '2019/Jul',
#  '2019/Ago',
#  '2019/Set',
#  '2019/Out',
#  '2019/Nov',
#  '2019/Dez',
#  '2020/Jan',
#  '2020/Fev',
#  '2020/Mar',
#  '2020/Abr',
#  '2020/Mai',
#  '2020/Jun',
#  '2020/Jul',
#  '2020/Ago',
#  '2020/Set',
#  '2020/Out',
#  '2020/Nov',
#  '2020/Dez',
#  '2021/Jan',
#  '2021/Fev',
#  '2021/Mar',
#  'Total']

# %%
usaveis = dados[colunas_usaveis]
usaveis.head()
# Out:
#   Unidade da Federação   2007/Ago  ...     2021/Mar         Total
# 0          11 Rondônia    4209.37  ...   4732441.04  9.964113e+08
# 1              12 Acre   10470.07  ...   1137341.65  4.500485e+08
# 2          13 Amazonas   35752.72  ...   6799060.80  1.917248e+09
# 3           14 Roraima    4785.91  ...   2381844.31  3.288770e+08
# 4              15 Pará  181159.29  ...  13069564.31  4.705309e+09
#
# [5 rows x 166 columns]

# %%
usaveis = usaveis.set_index("Unidade da Federação")
usaveis
# Out:
#                           2007/Ago    2007/Set  ...      2021/Mar         Total
# Unidade da Federação                            ...
# 11 Rondônia                4209.37    16397.03  ...  4.732441e+06  9.964113e+08
# 12 Acre                   10470.07    14001.71  ...  1.137342e+06  4.500485e+08
# 13 Amazonas               35752.72    45570.64  ...  6.799061e+06  1.917248e+09
# 43 Rio Grande do Sul      9.856615e+07
# 50 Mato Grosso do Sul     1.921798e+07
# 51 Mato Grosso            1.653234e+07
# 52 Goiás                  3.853357e+07
# 53 Distrito Federal       2.113336e+07
# Name: 2019/Ago, dtype: float64

# %%
usaveis.loc["12 Acre"]
# Out:
# 2007/Ago    1.047007e+04
# 2007/Set    1.400171e+04
# 2007/Out    8.620085e+04
# 2007/Nov    3.013237e+05
# 2007/Dez    7.696124e+05
#                 ...
# 2020/Dez    3.711661e+06
# 2021/Jan    3.005561e+06
# 2021/Fev    2.272734e+06
# 2021/Mar    1.137342e+06
# Total       4.500485e+08
# Name: 12 Acre, Length: 165, dtype: float64

# %%
usaveis.T.head()
# Out:
# Unidade da Federação  11 Rondônia    12 Acre  ...    52 Goiás  53 Distrito Federal
# 2007/Ago                  4209.37   10470.07  ...   179395.82            191951.47
# 2007/Set                 16397.03   14001.71  ...   418053.58            769966.25
# 2007/Out                133645.19   86200.85  ...  1198730.25           2165619.56
# 2007/Nov                346912.84  301323.68  ...  2712117.54           3813256.48
# 2007/Dez                711758.31  769612.36  ...  9293914.78           7121965.42
#
# [5 rows x 27 columns]

# %%
usaveis.T.plot(figsize=(10,6))

# %%
usaveis = usaveis.drop("Total", axis=1)
usaveis.head()
# Out:
#                        2007/Ago   2007/Set  ...     2021/Fev     2021/Mar
# Unidade da Federação                        ...
# 11 Rondônia             4209.37   16397.03  ...   6039419.59   4732441.04
# 12 Acre                10470.07   14001.71  ...   2272733.90   1137341.65
# 13 Amazonas            35752.72   45570.64  ...  13679358.06   6799060.80
# 14 Roraima              4785.91   11858.63  ...   3044798.77   2381844.31
# 15 Pará               181159.29  433414.74  ...  23343222.94  13069564.31
#
# [5 rows x 164 columns]

# %%
import matplotlib.pyplot as plt

usaveis.T.plot(figsize=(10,6))
plt.show()

# %% [markdown]
# ###Desafio 01: Reposicionar a legenda do gráfico em uma posição mais adequada
# Também foram ajustados os valores e casas decimais.

# %%
import matplotlib.ticker as ticker

ax = usaveis.T.plot(figsize=(10,6))
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter("{x:,.2f}"))
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
plt.show()

# %% [markdown]
# ###Desafio 02: Plotar o gráfico de linha com apenas 5 estados de sua preferência

# %%
top5 = usaveis.T
top5 = top5[["29 Bahia","31 Minas Gerais","33 Rio de Janeiro","35 São Paulo","41 Paraná"]]
top5.head()
# Out:
# Unidade da Federação     29 Bahia  31 Minas Gerais  ...  35 São Paulo    41 Paraná
# 2007/Ago                135146.36        971394.37  ...    1665349.90    554800.22
# 2007/Set                448349.75       2861781.50  ...    4434168.64   1431708.01
# 2007/Out               1382038.11      10018011.35  ...   14577395.84   4630402.44
# 2007/Nov               3348779.62      21730281.63  ...   35032259.98  11120030.79
# 2007/Dez              11948984.56      43429517.54  ...   76668547.41  28790722.87
#
# [5 rows x 5 columns]

# %%
ax = top5.plot(figsize=(10,6))
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter("{x:,.2f}"))
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
plt.show()
