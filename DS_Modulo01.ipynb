# %% [markdown]
# <a href="https://colab.research.google.com/github/brunarigo/datascience2-alurabootcamp/blob/main/DS_Modulo01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
dados = pd.read_csv("/content/A211434189_28_143_208_DTProcessamento.csv", encoding="ISO-8859-1", engine="python",
                    skiprows = 3, sep=";", skipfooter=11,
                    thousands=".", decimal=",")
dados.head()
# Out:
#   Região/Unidade da Federação    2008/Jan  ...    2021/Mar         Total
# 0                Região Norte 31111673.48  ... 78940416.89 9727782053.81
# 1                 .. Rondônia  1388528.39  ... 11023309.47  996411254.68
# 2                     .. Acre   902416.00  ...  4077045.92  450048530.47
# 3                 .. Amazonas  4735529.42  ... 22032176.22 1917247936.05
# 4                  .. Roraima   657889.53  ...  3985530.08  328876965.09
#
# [5 rows x 161 columns]

# %%
dados.tail()
# Out:
#    Região/Unidade da Federação     2008/Jan  ...      2021/Mar           Total
# 28       .. Mato Grosso do Sul   5377392.11  ...   25168195.34   2324525096.33
# 29              .. Mato Grosso   4795299.01  ...   19611032.61   2180119781.15
# 30                    .. Goiás  15310637.29  ...   45592686.49   4973573613.47
# 31         .. Distrito Federal   4745919.19  ...   31831917.45   2592422853.56
# 32                       Total 408424859.23  ... 1687562138.38 172481760138.88
#
# [5 rows x 161 columns]

# %%
pd.options.display.float_format = "{:.2f}".format

# %%
dados.mean()
# Out:
# 2008/Jan      37129532.66
# 2008/Fev      55743115.38
# 2008/Mar      60367550.76
# 2008/Abr      62423896.49
# 2008/Mai      65073058.14
#                 ...
# 2020/Dez     131018145.91
# 2021/Jan     137635563.32
# 2021/Fev     136419299.94
# 2021/Mar     153414739.85
# Total      15680160012.63
# Length: 159, dtype: float64

# %%
dados['2008/Jan']
# Out:
# 0     31111673.48
# 1      1388528.39
# 2       902416.00
# 3      4735529.42
# 4       657889.53
# 5     18864744.11
# 6      1120973.34
# 7      3441592.69
# 8     95549236.04
# 9     10723506.39
# 10     7985142.43
# 11    15539821.90
# 12     5947814.08
# 13    10723002.45
# 14    14393949.89
# 15     6243726.32
# 16     2780750.11
# 17    21211522.47
# 18   165832115.74
# 19    45671659.76
# 20     5456723.98
# 21    23025258.52
# 22    91678473.48
# 23    85702586.37
# 24    38266347.46
# 25    16504913.45
# 26    30931325.46
# 27    30229247.60
# 28     5377392.11
# 29     4795299.01
# 30    15310637.29
# 31     4745919.19
# 32   408424859.23
# Name: 2008/Jan, dtype: float64
